# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
dataset=pd.read_csv("homeprices.csv")
print(dataset)
# Out:
#     area   price
# 0   5865  643571
# 1   6941  333005
# 2   5672  262187
# 3   8287  239572
# 4   6219  568549
# 5   2003  833988
# 6   8678  943336
# 7   6988  187445
# 8   3313  927146
# 9   7449  916631
# 10  9947  422575
# 11  1471  711493
# 12  5305  735745
# 13  8365  677944
# 14  8467  929782
# 15  5348  877448
# 16  2734  419406
# 17  2804  101906
# 18  4073  682235
# 19  1680  198384

# %%
x=dataset.iloc[:,0:1].values
y=dataset.iloc[:,-1].values
print(x)
print(y)
# Out:
# [[5865]
#  [6941]
#  [5672]
#  [8287]
#  [6219]
#  [2003]
#  [8678]
#  [6988]
#  [3313]
#  [7449]
#  [9947]
#  [1471]
#  [5305]
#  [8365]
#  [8467]
#  [5348]
#  [2734]
#  [2804]
#  [4073]
#  [1680]]
# [643571 333005 262187 239572 568549 833988 943336 187445 927146 916631
#  422575 711493 735745 677944 929782 877448 419406 101906 682235 198384]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=1)
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x_train,y_train)
# y_test=lr.predict(x_test)
print(x_test)
print(y_test)
# Out:
# [[8287]
#  [2734]
#  [8678]
#  [9947]]
# [656414.25037483 556038.30989995 663481.96021198 686420.38421029]

# %%
plt.scatter(x_train,y_train,color='red',marker='*',s=100)
plt.plot(x_train,lr.predict(x_train),color='blue')
plt.title('price vs area')
plt.xlabel('area')
plt.ylabel('price')
# Out:
# Text(0, 0.5, 'price')
